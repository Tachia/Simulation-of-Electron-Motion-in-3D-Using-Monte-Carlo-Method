# %% [markdown]
# <a href="https://colab.research.google.com/github/Tachia/Simulation-of-Electron-Motion-in-3D-Using-Monte-Carlo-Method/blob/main/Simulation_of_Electron_in_3D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# MONTE CARLO SIMULATION TASK
#
# QUESTION:
#
# Show the trajectory of an electron motion in 3D using Monte Carlo Simulation, and hence determine the angles, phi (φ), theta (θ) and the mean free path, lambda (Λ) for: ten (10), hundred (100) a thousand (1000) and tens of thousand (10000) collisions.
#
# Given that:
#
# Phi (φ) = 2πa, a --- [0,1] "random valuable"
#
# Theta (θ) = arccos(1-2a)
#
# Lambda (Λ) = -λ.ln(a)
#
# NB: The value of "a" must be selected differently for each collision(s).
#
# where: Phi, φ and theta θ, are the angles between the electron collisions with other particles, a - is Bohr radius, lambda, Λ - is the mean free path, λ - is lambda null which is assumed to be 1, ln(a) - is the natural logarithsm of a in base e.

# %%
#@title
import numpy as np
import matplotlib.pyplot as plt
import random

numbere = 1
num_a = 10
e = []
for j in range(numbere):
  ax = plt.axes(projection="3d")
  a = np.random.uniform(size=num_a)
  b = np.random.uniform(size=num_a)
  c = np.random.uniform(size=num_a)
  ex = [0]
  ey = [0]
  ez = [0]
  for i in range(len(a)):
    Lambda = -np.log(b[i])
    phi = 2*np.pi*a[i]
    theta = np.arccos(1 - 2*c[i])

    ex.append(Lambda*np.cos(phi))
    ey.append(Lambda*np.sin(phi))
    ez.append(Lambda*theta)
  plt.plot(ex, ey, ez, linestyle='-',color ="navy", linewidth = 3, marker='o', markerfacecolor='green', markersize=10)
plt.show()

# Absolute value of the graph
L = []
a = np.random.uniform(size=num_a)
b = np.random.uniform(size=num_a)
c = np.random.uniform(size=num_a)
ex = [0]
ey = [0]
ez = [0]

for i in range(len(a)):
  Lambda = -np.log(b[i])
  phi = 2*np.pi*a[i]
  theta = np.arccos(1 - 2*c[i])

  ex.append(Lambda*np.cos(phi))
  ey.append(Lambda*np.sin(phi))
  ez.append(Lambda*theta)
lx = 0
ly = 0
lz = 0
N = []
n = 1
for i in range(len(a)):
  N.append(n)
  n = n + 1
  lx = lx + abs(ex[i])
  ly = ly + abs(ey[i])
  lz = lz + abs(ez[i])
  L.append(((lx+ly+lz)**(1/2)))

plt.plot(N, L, color ="darkblue")
plt.title("The Distance from the Source against Number of Collisions: Absolute Values")
plt.xlabel("Number of Collisions")
plt.ylabel("The Distance from the Source")
plt.show()

# %%
#@title
import numpy as np
import matplotlib.pyplot as plt
import random

numbere = 1
num_a = 100
e = []
for j in range(numbere):
  ax = plt.axes(projection="3d")
  a = np.random.uniform(size=num_a)
  b = np.random.uniform(size=num_a)
  c = np.random.uniform(size=num_a)
  ex = [0]
  ey = [0]
  ez = [0]
  for i in range(len(a)):
    Lambda = -np.log(b[i])
    phi = 2*np.pi*a[i]
    theta = np.arccos(1 - 2*c[i])

    ex.append(Lambda*np.cos(phi))
    ey.append(Lambda*np.sin(phi))
    ez.append(Lambda*theta)
  plt.plot(ex, ey, ez, linestyle='-',color ="navy", linewidth = 3, marker='o', markerfacecolor='green', markersize=10)
plt.show()

# Absolute value of the graph
L = []
a = np.random.uniform(size=num_a)
b = np.random.uniform(size=num_a)
c = np.random.uniform(size=num_a)
ex = [0]
ey = [0]
ez = [0]

for i in range(len(a)):
  Lambda = -np.log(b[i])
  phi = 2*np.pi*a[i]
  theta = np.arccos(1 - 2*c[i])

  ex.append(Lambda*np.cos(phi))
  ey.append(Lambda*np.sin(phi))
  ez.append(Lambda*theta)
lx = 0
ly = 0
lz = 0
N = []
n = 1
for i in range(len(a)):
  N.append(n)
  n = n + 1
  lx = lx + abs(ex[i])
  ly = ly + abs(ey[i])
  lz = lz + abs(ez[i])
  L.append(((lx+ly+lz)**(1/2)))

plt.plot(N, L, color ="darkblue")
plt.title("The Distance from the Source against Number of Collisions: Absolute Values")
plt.xlabel("Number of Collisions")
plt.ylabel("The Distance from the Source")
plt.show()

# %%
#@title
import numpy as np
import matplotlib.pyplot as plt
import random

numbere = 1
num_a = 1000
e = []
for j in range(numbere):
  ax = plt.axes(projection="3d")
  a = np.random.uniform(size=num_a)
  b = np.random.uniform(size=num_a)
  c = np.random.uniform(size=num_a)
  ex = [0]
  ey = [0]
  ez = [0]
  for i in range(len(a)):
    Lambda = -np.log(b[i])
    phi = 2*np.pi*a[i]
    theta = np.arccos(1 - 2*c[i])

    ex.append(Lambda*np.cos(phi))
    ey.append(Lambda*np.sin(phi))
    ez.append(Lambda*theta)
  plt.plot(ex, ey, ez, linestyle='-',color ="navy", linewidth = 3, marker='o', markerfacecolor='green', markersize=10)
plt.show()

# Absolute value of the graph
L = []
a = np.random.uniform(size=num_a)
b = np.random.uniform(size=num_a)
c = np.random.uniform(size=num_a)
ex = [0]
ey = [0]
ez = [0]

for i in range(len(a)):
  Lambda = -np.log(b[i])
  phi = 2*np.pi*a[i]
  theta = np.arccos(1 - 2*c[i])

  ex.append(Lambda*np.cos(phi))
  ey.append(Lambda*np.sin(phi))
  ez.append(Lambda*theta)
lx = 0
ly = 0
lz = 0
N = []
n = 1
for i in range(len(a)):
  N.append(n)
  n = n + 1
  lx = lx + abs(ex[i])
  ly = ly + abs(ey[i])
  lz = lz + abs(ez[i])
  L.append(((lx+ly+lz)**(1/2)))

plt.plot(N, L, color ="darkblue")
plt.title("The Distance from the Source against Number of Collisions: Absolute Values")
plt.xlabel("Number of Collisions")
plt.ylabel("The Distance from the Source")
plt.show()

# %%
#@title
import numpy as np
import matplotlib.pyplot as plt
import random

numbere = 1
num_a = 10000
e = []
for j in range(numbere):
  ax = plt.axes(projection="3d")
  a = np.random.uniform(size=num_a)
  b = np.random.uniform(size=num_a)
  c = np.random.uniform(size=num_a)
  ex = [0]
  ey = [0]
  ez = [0]
  for i in range(len(a)):
    Lambda = -np.log(b[i])
    phi = 2*np.pi*a[i]
    theta = np.arccos(1 - 2*c[i])

    ex.append(Lambda*np.cos(phi))
    ey.append(Lambda*np.sin(phi))
    ez.append(Lambda*theta)
  plt.plot(ex, ey, ez, linestyle='-',color ="navy", linewidth = 3, marker='o', markerfacecolor='green', markersize=10)
plt.show()

# Absolute value of the graph
L = []
a = np.random.uniform(size=num_a)
b = np.random.uniform(size=num_a)
c = np.random.uniform(size=num_a)
ex = [0]
ey = [0]
ez = [0]

for i in range(len(a)):
  Lambda = -np.log(b[i])
  phi = 2*np.pi*a[i]
  theta = np.arccos(1 - 2*c[i])

  ex.append(Lambda*np.cos(phi))
  ey.append(Lambda*np.sin(phi))
  ez.append(Lambda*theta)
lx = 0
ly = 0
lz = 0
N = []
n = 1
for i in range(len(a)):
  N.append(n)
  n = n + 1
  lx = lx + abs(ex[i])
  ly = ly + abs(ey[i])
  lz = lz + abs(ez[i])
  L.append(((lx+ly+lz)**(1/2)))

plt.plot(N, L, color ="darkblue")
plt.title("The Distance from the Source against Number of Collisions: Absolute Values")
plt.xlabel("Number of Collisions")
plt.ylabel("The Distance from the Source")
plt.show()

# %% [markdown]
# Next, using ten samples of electron to simulatate the ramdom motion of electrons in 3D by Monthe Carlo Method.

# %%
#@title
import numpy as np
import matplotlib.pyplot as plt
import random

numbere = 10
num_a = 1000
e = []
for j in range(numbere):
  ax = plt.axes(projection="3d")
  a = np.random.uniform(size=num_a)
  b = np.random.uniform(size=num_a)
  c = np.random.uniform(size=num_a)
  ex = [0]
  ey = [0]
  ez = [0]
  for i in range(len(a)):
    Lambda = -np.log(b[i])
    phi = 2*np.pi*a[i]
    theta = np.arccos(1 - 2*c[i])

    ex.append(Lambda*np.cos(phi))
    ey.append(Lambda*np.sin(phi))
    ez.append(Lambda*theta)
  plt.plot(ex, ey, ez, linestyle='-',color ="navy", linewidth = 3, marker='o', markerfacecolor='green', markersize=10)
plt.show()

# Absolute value of the graph
L = []
a = np.random.uniform(size=num_a)
b = np.random.uniform(size=num_a)
c = np.random.uniform(size=num_a)
ex = [0]
ey = [0]
ez = [0]

for i in range(len(a)):
  Lambda = -np.log(b[i])
  phi = 2*np.pi*a[i]
  theta = np.arccos(1 - 2*c[i])

  ex.append(Lambda*np.cos(phi))
  ey.append(Lambda*np.sin(phi))
  ez.append(Lambda*theta)
lx = 0
ly = 0
lz = 0
N = []
n = 1
for i in range(len(a)):
  N.append(n)
  n = n + 1
  lx = lx + abs(ex[i])
  ly = ly + abs(ey[i])
  lz = lz + abs(ez[i])
  L.append(((lx+ly+lz)**(1/2)))

plt.plot(N, L, color ="darkblue")
plt.title("The Distance from the Source against Number of Collisions: Absolute Values")
plt.xlabel("Number of Collisions")
plt.ylabel("The Distance from the Source")
plt.show()

# %%
#@title
import numpy as np
import matplotlib.pyplot as plt
import random

numbere = 10
num_a = 100000
e = []
for j in range(numbere):
  ax = plt.axes(projection="3d")
  a = np.random.uniform(size=num_a)
  b = np.random.uniform(size=num_a)
  c = np.random.uniform(size=num_a)
  ex = [0]
  ey = [0]
  ez = [0]
  for i in range(len(a)):
    Lambda = -np.log(b[i])
    phi = 2*np.pi*a[i]
    theta = np.arccos(1 - 2*c[i])

    ex.append(Lambda*np.cos(phi))
    ey.append(Lambda*np.sin(phi))
    ez.append(Lambda*theta)
  plt.plot(ex, ey, ez, linestyle='-',color ="navy", linewidth = 3, marker='o', markerfacecolor='green', markersize=10)
plt.show()

# Absolute value of the graph
L = []
a = np.random.uniform(size=num_a)
b = np.random.uniform(size=num_a)
c = np.random.uniform(size=num_a)
ex = [0]
ey = [0]
ez = [0]

for i in range(len(a)):
  Lambda = -np.log(b[i])
  phi = 2*np.pi*a[i]
  theta = np.arccos(1 - 2*c[i])

  ex.append(Lambda*np.cos(phi))
  ey.append(Lambda*np.sin(phi))
  ez.append(Lambda*theta)
lx = 0
ly = 0
lz = 0
N = []
n = 1
for i in range(len(a)):
  N.append(n)
  n = n + 1
  lx = lx + abs(ex[i])
  ly = ly + abs(ey[i])
  lz = lz + abs(ez[i])
  L.append(((lx+ly+lz)**(1/2)))

plt.plot(N, L, color ="darkblue")
plt.title("The Distance from the Source against Number of Collisions: Absolute Values")
plt.xlabel("Number of Collisions")
plt.ylabel("The Distance from the Source")
plt.show()
